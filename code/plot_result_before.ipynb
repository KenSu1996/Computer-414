# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import seaborn as sns
import pickle
from sklearn.metrics import det_curve, roc_curve, roc_auc_score

# %% [markdown]
# # Ethnicity

# %%
with open('../results/verification_ethnicity_all_Pretrained.pkl', 'rb') as f:
        loaded_dict_g_cmu = pickle.load(f)
loaded_list_g_cmu = []
for k in  loaded_dict_g_cmu.keys():
    loaded_list_g_cmu.append(loaded_dict_g_cmu[k])
std_gar_cmu = []
far = []
for key in loaded_list_g_cmu[0].keys():
    temp = []
    for i in range(len(loaded_list_g_cmu)):
        try:
            temp.append(loaded_list_g_cmu[i][key])
        except:
            continue
    std_gar_cmu.append(np.std(temp, ddof=1)*100)
    far.append(key*100)

# %%
# Define fixed x positions for four bars
x = [1, 2, 3, 4]
bar_width = 0.35  # Fixed width for each bar

# Plot the first set of bars
plt.bar(x, std_gar_cmu[0:4], bar_width, align='edge', facecolor='dodgerblue', edgecolor='white', lw=2, label='Synthetic Faces')
for i in range(4):
    plt.annotate(str(std_gar_cmu[i]), xy=(x[i], std_gar_cmu[i]), ha='left', va='bottom')



plt.xlabel("FAR(%)")
plt.ylabel("GAR Standard Deviation")
plt.title("FAR Vs Std(GAR) - Ethnicity")
plt.legend()
plt.show()

# %% [markdown]
# # Gender

# %%
with open('../results/verification_gender_all_Pretrained.pkl', 'rb') as f:
        loaded_dict_g_cmu = pickle.load(f)
loaded_list_g_cmu = []
for k in  loaded_dict_g_cmu.keys():
    loaded_list_g_cmu.append(loaded_dict_g_cmu[k])
std_gar_cmu = []
far = []
for key in loaded_list_g_cmu[0].keys():
    temp = []
    for i in range(len(loaded_list_g_cmu)):
        try:
            temp.append(loaded_list_g_cmu[i][key])
        except:
            continue
    std_gar_cmu.append(np.std(temp, ddof=1)*100)
    far.append(key*100)

# %%
print(std_gar_cmu)
# Out:
# [3.8771289837751635, 3.109972379039377, 0.04530980582819761, 0.20904712567839703, 0.15574864614429548, 0.014635738087163837, 0.00975715872477851, 0.1362343286947385, nan, 0.0]

# %%
plt.bar(x, std_gar_cmu[0:4], bar_width, align='edge', facecolor='dodgerblue', edgecolor='white', lw=2, label='Synthetic Faces')
for i in range(4):
    plt.annotate(str(std_gar_cmu[i]), xy=(x[i], std_gar_cmu[i]), ha='left', va='bottom')
plt.xlabel("FAR(%)")
plt.ylabel("GAR Standard Deviation")
plt.title("FAR Vs Std(GAR) - Gender")
plt.legend()
plt.show()

# %% [markdown]
# # Attributes

# %%
with open('../results/verification_attributes_all_Pretrained.pkl', 'rb') as f:
        loaded_dict_g_cmu = pickle.load(f)
loaded_list_g_cmu = []
for k in  loaded_dict_g_cmu.keys():
    loaded_list_g_cmu.append(loaded_dict_g_cmu[k])
std_gar_cmu = []
far = []
for key in loaded_list_g_cmu[0].keys():
    temp = []
    for i in range(len(loaded_list_g_cmu)):
        try:
            temp.append(loaded_list_g_cmu[i][key])
        except:
            continue
    std_gar_cmu.append(np.std(temp, ddof=1)*100)
    far.append(key*100)

# %%
plt.bar(x, std_gar_cmu[0:4], bar_width, align='edge', facecolor='dodgerblue', edgecolor='white', lw=2, label='Synthetic Faces')
for i in range(4):
    plt.annotate(str(std_gar_cmu[i]), xy=(x[i], std_gar_cmu[i]), ha='left', va='bottom')
plt.xlabel("FAR(%)")
plt.ylabel("GAR Standard Deviation")
plt.title("FAR Vs Std(GAR) - Attributes")
plt.legend()
plt.show()
